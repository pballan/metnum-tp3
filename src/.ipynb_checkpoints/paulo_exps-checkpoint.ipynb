# %%
import pandas as pd
import numpy as np
import seaborn as sns; sns.set_style("darkgrid")
from sklearn import linear_model
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import random

import warnings
warnings.filterwarnings('ignore')

# %%
# Levanto los datos

df = pd.read_csv('../data/temperaturas_catedra/GlobalLandTemperaturesByCountry.csv')
df_lat_long = pd.read_csv('../data/long_lat/cities_lat_long.csv')

df = pd.merge(df, df_lat_long, on='Country')

df2 = df[(df['lng'] < -58) & (df['lng'] > -61)]
df3 = df2[(df2['lat'] < 10) & (df2['lat'] > -40)]





df3.dropna(axis=1, how='any')
#df
# Out:
#                   dt    Country                          city  \
# 418317    1855-05-01  Argentina                   San Nicolas
# 418318    1855-05-01  Argentina                       Campana
# 418319    1855-05-01  Argentina                     Chacabuco
# 418320    1855-05-01  Argentina                      Mercedes
# 418322    1855-05-01  Argentina                     Chivilcoy
# 418323    1855-05-01  Argentina           Veinticinco de Mayo
# 418324    1855-05-01  Argentina                Nueve de Julio
# 418327    1855-05-01  Argentina                  Tres Arroyos
# 418329    1855-05-01  Argentina                      Balcarce
# 418353    1855-05-01  Argentina  Presidencia Roque Saenz Pena
# 418355    1855-05-01  Argentina                  Villa Angela
# 418357    1855-05-01  Argentina            Comandante Fontana
# 418359    1855-05-01  Argentina                   San Lorenzo
# 418360    1855-05-01  Argentina                    Corrientes
# 418361    1855-05-01  Argentina        Concepcion del Uruguay
# 418362    1855-05-01  Argentina                      Victoria
# 418363    1855-05-01  Argentina                     Gualeguay
# 418364    1855-05-01  Argentina                        Parana
# 418365    1855-05-01  Argentina            Villa Constitucion
# 418377    1855-05-01  Argentina                        Zarate
# 418380    1855-05-01  Argentina                        Juarez
# 418382    1855-05-01  Argentina                         Lobos
# 418383    1855-05-01  Argentina                     Chascomus
# 418384    1855-05-01  Argentina                         Junin
# 418386    1855-05-01  Argentina                     Pergamino
# 418387    1855-05-01  Argentina                         Lujan
# 418388    1855-05-01  Argentina                          Azul
# 418409    1855-05-01  Argentina            Juan Jose Castelli
# 418411    1855-05-01  Argentina                   Las Lomitas
# 418412    1855-05-01  Argentina                      Mercedes
# ...              ...        ...                           ...
# 13398619  2013-02-01    Uruguay                      Mercedes
# 13398626  2013-02-01    Uruguay                      Paysandu
# 13398632  2013-03-01    Uruguay                   Fray Bentos
# 13398649  2013-03-01    Uruguay                       Carmelo
# 13398651  2013-03-01    Uruguay                      Mercedes
# 13398658  2013-03-01    Uruguay                      Paysandu
# 13398664  2013-04-01    Uruguay                   Fray Bentos
# 13398681  2013-04-01    Uruguay                       Carmelo
# 13398683  2013-04-01    Uruguay                      Mercedes
# 13398690  2013-04-01    Uruguay                      Paysandu
# 13398696  2013-05-01    Uruguay                   Fray Bentos
# 13398713  2013-05-01    Uruguay                       Carmelo
# 13398715  2013-05-01    Uruguay                      Mercedes
# 13398722  2013-05-01    Uruguay                      Paysandu
# 13398728  2013-06-01    Uruguay                   Fray Bentos
# 13398745  2013-06-01    Uruguay                       Carmelo
# 13398747  2013-06-01    Uruguay                      Mercedes
# 13398754  2013-06-01    Uruguay                      Paysandu
# 13398760  2013-07-01    Uruguay                   Fray Bentos
# 13398777  2013-07-01    Uruguay                       Carmelo
# 13398779  2013-07-01    Uruguay                      Mercedes
# 13398786  2013-07-01    Uruguay                      Paysandu
# 13398728                   Fray Bentos -33.138999 -58.303997   23279.0   UY
# 13398745                       Carmelo -33.989619 -58.299992   15113.5   UY
# 13398747                      Mercedes -33.259534 -58.029983   41951.5   UY
# 13398754                      Paysandu -32.329979 -58.079980   76132.5   UY
# 13398760                   Fray Bentos -33.138999 -58.303997   23279.0   UY
# 13398777                       Carmelo -33.989619 -58.299992   15113.5   UY
# 13398779                      Mercedes -33.259534 -58.029983   41951.5   UY
# 13398786                      Paysandu -32.329979 -58.079980   76132.5   UY
# 13398792                   Fray Bentos -33.138999 -58.303997   23279.0   UY
# 13398809                       Carmelo -33.989619 -58.299992   15113.5   UY
# 13398811                      Mercedes -33.259534 -58.029983   41951.5   UY
# 13398818                      Paysandu -32.329979 -58.079980   76132.5   UY
# 13398824                   Fray Bentos -33.138999 -58.303997   23279.0   UY
# 13398841                       Carmelo -33.989619 -58.299992   15113.5   UY
# 13398843                      Mercedes -33.259534 -58.029983   41951.5   UY
# 13398850                      Paysandu -32.329979 -58.079980   76132.5   UY
#
#          iso3                province
# 418317    ARG  Ciudad de Buenos Aires
# 418318    ARG  Ciudad de Buenos Aires
# 418319    ARG  Ciudad de Buenos Aires
# 418320    ARG  Ciudad de Buenos Aires
# 418322    ARG  Ciudad de Buenos Aires
# 418323    ARG  Ciudad de Buenos Aires
# 418324    ARG  Ciudad de Buenos Aires
# 418327    ARG  Ciudad de Buenos Aires
# 418329    ARG  Ciudad de Buenos Aires
# 418353    ARG                   Chaco
# 418355    ARG                   Chaco
# 418357    ARG                 Formosa
# 418359    ARG              Corrientes
# 418360    ARG              Corrientes
# 418361    ARG              Entre Ríos
# 418362    ARG              Entre Ríos
# 418363    ARG              Entre Ríos
# 418364    ARG              Entre Ríos
# 418365    ARG                Santa Fe
# 418377    ARG  Ciudad de Buenos Aires
# 418380    ARG  Ciudad de Buenos Aires
# 418382    ARG  Ciudad de Buenos Aires
# 418383    ARG  Ciudad de Buenos Aires
# 418384    ARG  Ciudad de Buenos Aires
# 418386    ARG  Ciudad de Buenos Aires
# 418387    ARG  Ciudad de Buenos Aires
# 418388    ARG  Ciudad de Buenos Aires
# 418409    ARG                   Chaco
# 418411    ARG                 Formosa
# 418412    ARG              Corrientes
# ...       ...                     ...
# 13398619  URY                 Soriano
# 13398626  URY                Paysandú
# 13398632  URY               Río Negro
# 13398649  URY                 Colonia
# 13398651  URY                 Soriano
# 13398658  URY                Paysandú
# 13398664  URY               Río Negro
# 13398681  URY                 Colonia
# 13398683  URY                 Soriano
# 13398690  URY                Paysandú
# 13398696  URY               Río Negro
# 13398713  URY                 Colonia
# 13398715  URY                 Soriano
# 13398722  URY                Paysandú
# 13398728  URY               Río Negro
# 13398745  URY                 Colonia
# 13398747  URY                 Soriano
# 13398754  URY                Paysandú
# 13398760  URY               Río Negro
# 13398777  URY                 Colonia
# 13398779  URY                 Soriano
# 13398786  URY                Paysandú
# 13398792  URY               Río Negro
# 13398809  URY                 Colonia
# 13398811  URY                 Soriano
# 13398818  URY                Paysandú
# 13398824  URY               Río Negro
# 13398841  URY                 Colonia
# 13398843  URY                 Soriano
# 13398850  URY                Paysandú
#
# [157166 rows x 10 columns]

# %%
# Gráficos los datos


df3['year'] = pd.DatetimeIndex(df3['dt']).year

df4 = df3.groupby(['year', 'city']).mean().reset_index()

df5 = df4[(df4['year'] < 2010) & (df4['year'] > 1900)]

samples = df5.sample(n=5)

citiesToTrain = samples['city']
cityToPredict = df5.sample(n=1)

if cityToPredict.isin(samples)['city'].all():  
    df5 = df5[df5['city'].isin(citiesToTrain)]
    df6 = df5.groupby(['year']).mean()
    df6
else:
    print('asdsad')

    

#grouped = df2.groupby(['year']).mean().reset_index()

#ax = sns.tsplot(data=grouped['AverageTemperature'], time=grouped['year'], interpolate=True)
#sns.plt.show()
# Out:
# asdsad

# %%
print("Decripción de los datos")
print(df3.describe())

print("\nLas primeras 8 filas de los datos")
print(df3.head(10))
# Out:
# Decripción de los datos
#        AverageTemperature  AverageTemperatureUncertainty            lat  \
# count       154488.000000                  154488.000000  157166.000000
# mean            18.614408                       0.597884     -22.481692
# std              6.120272                       0.497754      14.249375
# min              4.796000                       0.060000     -38.559986
# 25%             13.544000                       0.237000     -33.899599
# 50%             19.802000                       0.389000     -27.583292
# 75%             24.310000                       0.833000     -15.000029
# max             29.499000                       5.021000       8.199976
#
#                  lng           pop
# count  157166.000000  1.571660e+05
# mean      -59.537763  2.456716e+05
# std         0.962600  1.309884e+06
# min       -60.960011 -9.900000e+01
# 25%       -60.489988  9.421000e+03
# 50%       -59.759981  2.698300e+04
# 75%       -58.500057  7.144800e+04
# max       -58.016624  1.186207e+07
#
# Las primeras 8 filas de los datos
#                 dt  AverageTemperature  AverageTemperatureUncertainty  \
# 418317  1855-05-01              10.745                          1.499
# 418318  1855-05-01              10.745                          1.499
# 418319  1855-05-01              10.745                          1.499
# 418320  1855-05-01              10.745                          1.499
# 418322  1855-05-01              10.745                          1.499
# 418323  1855-05-01              10.745                          1.499
# 418324  1855-05-01              10.745                          1.499
# 418327  1855-05-01              10.745                          1.499
# 418329  1855-05-01              10.745                          1.499
# 418353  1855-05-01              10.745                          1.499
#
#           Country                          city                    city_ascii  \
# 418317  Argentina                   San Nicolas                   San Nicolas
# 418318  Argentina                       Campana                       Campana
# 418319  Argentina                     Chacabuco                     Chacabuco
# 418320  Argentina                      Mercedes                      Mercedes
# 418322  Argentina                     Chivilcoy                     Chivilcoy
# 418323  Argentina           Veinticinco de Mayo           Veinticinco de Mayo
# 418324  Argentina                Nueve de Julio                Nueve de Julio
# 418327  Argentina                  Tres Arroyos                  Tres Arroyos
# 418329  Argentina                      Balcarce                      Balcarce
# 418353  Argentina  Presidencia Roque Saenz Pena  Presidencia Roque Saenz Pena
#
#               lat        lng       pop iso2 iso3                province
# 418317 -33.330021 -60.240003  117123.5   AR  ARG  Ciudad de Buenos Aires
# 418318 -34.159996 -58.959978   77149.5   AR  ARG  Ciudad de Buenos Aires
# 418319 -34.650044 -60.489988   26645.0   AR  ARG  Ciudad de Buenos Aires
# 418320 -34.660017 -59.440026   48408.5   AR  ARG  Ciudad de Buenos Aires
# 418322 -34.899951 -60.039989   43719.0   AR  ARG  Ciudad de Buenos Aires
# 418323 -35.429996 -60.179981   18749.0   AR  ARG  Ciudad de Buenos Aires
# 418324 -35.445964 -60.889989   26716.0   AR  ARG  Ciudad de Buenos Aires
# 418327 -38.369972 -60.269949   34773.5   AR  ARG  Ciudad de Buenos Aires
# 418329 -37.833312 -58.249995   18967.0   AR  ARG  Ciudad de Buenos Aires
# 418353 -26.790007 -60.450016   75958.0   AR  ARG                   Chaco

# %%
# Limpio los outliers

def mascara_outliers(s):
    return abs(s - s.mean()) <= 2*s.std()
    
mascara = mascara_outliers(grouped['AverageTemperature'])
grouped = grouped[mascara]
sns.tsplot(data=grouped['AverageTemperature'], interpolate=True)
sns.plt.show()

# %%
# Uso cuadrados mínimos para predecir
sns.tsplot(data=grouped['AverageTemperature'], time=grouped['year'], interpolate=True, color='b')


def armar_matriz_A(s):
    temp = []
    for t in s:
        temp.append([t^4, t^3, t^2, t, 1, np.sin(t)])
    return np.array(temp)

def entrenar_y_predecir_en_rangos(df, rango_entrenamiento, rango_prediccion):
    regr = linear_model.LinearRegression(fit_intercept=False)

    # Entreno el modelo
    df_e = df[df['year'].isin(rango_entrenamiento)]
    A_e = armar_matriz_A(df_e['year'])
    regr.fit(A_e, df_e['AverageTemperature'])

    # Me fijo la aproximación que se realizó
    df_e['p'] = regr.predict(A_e)
    sns.tsplot(time=df_e['year'], data=df_e['p'], color='r')

    # Realizo predicciones
    df_p = df[df['year'].isin(rango_prediccion)]

    A_p = armar_matriz_A(df_p['year'])
    df_p['p'] = regr.predict(A_p)
    sns.tsplot(time=df_p['year'], data=df_p['p'], color='g')

    ECM = sum((df_p['p']-df_p['AverageTemperature'])**2)
    return ECM

def predecir(k):
    return entrenar_y_predecir_en_rangos(grouped, range(k-20,k), range(k,k+20))
    
ECM = predecir(1990)
print("Error de predicción: {:.2f}".format(ECM))
#ECM = predecir(50)
#print("Error de predicción: {:.2f}".format(ECM))
#ECM = predecir(30)
#print("Error de predicción: {:.2f}".format(ECM))
    
sns.plt.xlim((1970,2000))
sns.plt.show()
# Out:
# Error de predicción: 3.04

# %% [markdown]
# # Y si no es una seria de tiempo?

# %%
# Un par de cosas más de pandas

years = [2004]*6 + [2005]*6 + [2006]*6
delays = list(np.random.randn(6)+80) + list(np.random.randn(6)+5) + list(np.random.randn(6)+50)
delays[2] = 5
delays[7] = 80

df1 = pd.DataFrame({
    'year': years,
    'delay': delays
})

df1
# Out:
#         delay  year
# 0   80.821911  2004
# 1   81.994264  2004
# 2    5.000000  2004
# 3   77.742141  2004
# 4   80.080482  2004
# 5   80.356484  2004
# 6    4.082986  2005
# 7   80.000000  2005
# 8    5.537343  2005
# 9    5.836535  2005
# 10   5.402303  2005
# 11   5.086106  2005
# 12  50.606251  2006
# 13  50.135174  2006
# 14  50.751529  2006
# 15  50.293271  2006
# 16  51.094942  2006
# 17  48.922509  2006

# %%
# Groupby y sacar outliers

mascara = df1.groupby('year')['delay'].apply(mascara_outliers)
df1 = df1[mascara]
df1
# Out:
#         delay  year
# 0   80.821911  2004
# 1   81.994264  2004
# 3   77.742141  2004
# 4   80.080482  2004
# 5   80.356484  2004
# 6    4.082986  2005
# 8    5.537343  2005
# 9    5.836535  2005
# 10   5.402303  2005
# 11   5.086106  2005
# 12  50.606251  2006
# 13  50.135174  2006
# 14  50.751529  2006
# 15  50.293271  2006
# 16  51.094942  2006
# 17  48.922509  2006

# %%
# Groupby y calcular promedio

promedio = df1.groupby('year').aggregate(['mean', 'std', 'count'])
promedio
# Out:
#           delay
#            mean       std count
# year
# 2004  80.199056  1.556117     5
# 2005   5.189055  0.674536     5
# 2006  50.300613  0.755552     6
