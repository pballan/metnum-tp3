# %%
import pandas as pd
import numpy as np
import seaborn as sns; sns.set_style("darkgrid")
from sklearn import linear_model
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import random
import matplotlib.patches as mpatches

import warnings
warnings.filterwarnings('ignore')

# %%
# Levanto los datos


def crear_anio(datos,tag):
    return datos[tag].apply (lambda x : x.year if x.month < 12 else x.year + 1)
def crear_mes(datos,tag):
    return datos[tag].apply (lambda x : x.month)

data_temperatura = pd.read_csv('../data/temperaturas_catedra/GlobalLandTemperaturesByCity.csv', parse_dates=['dt'])

data_lat_long = pd.read_csv('../data/long_lat/cities_lat_long.csv')

df = pd.merge(data_temperatura, data_lat_long, on=['City', 'Country'])


#df = df.dropna(axis=1, how='any')
#df = df.drop('iso2',1)
#df = df.drop('iso3', 1)
#df = df.drop('pop', 1)
#df = df.drop('Latitude', 1)
#df = df.drop('Longitude', 1)

# %%
df_testing = df

df_testing['month'] = crear_mes(df_testing, 'dt')
df_testing['year'] = crear_anio(df_testing, 'dt')

# %%
# Gráficos los datos

df_new = df_testing[(df_testing['lng'] < -65) & (df_testing['lng'] > -75) & (df_testing['lat'] < 40) & (df_testing['lat'] > -50)]


df_new = df_new[(df_new['month'] == 12) & (df_new['year'] == 2011)]

Oruro = df_new[df_new['City'] == 'Oruro']
Santiago = df_new[df_new['City'] == 'Santiago']
Maracaibo = df_new[df_new['City'] == 'Maracaibo']

grouped = df_new[(df_new['City'] != 'oruro') & (df_new['City'] != 'Santiago') & (df_new['City'] != 'Maracaibo')]

#grouped['City']

grouped = grouped.groupby(['City']).min()

Oruro = {
    "avg": Oruro['AverageTemperature'].iloc[0],
    "lat": Oruro['lat'].iloc[0]
}

Maracaibo = {
    "avg": Maracaibo['AverageTemperature'].iloc[0],
    "lat": Maracaibo['lat'].iloc[0]
}

Santiago = {
    "avg": Santiago['AverageTemperature'].iloc[0],
    "lat": Santiago['lat'].iloc[0]
}


grouped.head(1000)
# Out:
#                         dt  AverageTemperature  AverageTemperatureUncertainty  \
# City
# Acarigua        2010-12-01              27.553                          0.540
# Antofagasta     2010-12-01              16.741                          0.678
# Arequipa        2010-12-01              20.236                          0.584
# Arica           2010-12-01              19.320                          0.526
# Ayacucho        2010-12-01              11.360                          0.668
# Barinas         2010-12-01              23.598                          0.667
# Barquisimeto    2010-12-01              24.980                          0.570
# Barrancabermeja 2010-12-01              24.877                          0.503
# Barranquilla    2010-12-01              26.121                          0.297
# Bucaramanga     2010-12-01              24.877                          0.503
# Cabimas         2010-12-01              26.796                          0.380
# Calabozo        2010-12-01              28.403                          0.410
# Calama          2010-12-01              17.048                          0.858
# Caracas         2010-12-01              25.275                          0.647
# Catamarca       2010-12-01              25.617                          0.460
# Chillan         2010-12-01              16.739                          0.859
# Cochabamba      2010-12-01              17.815                          0.442
# Concepcion      2010-12-01              13.599                          0.619
# Copiapo         2010-12-01              13.471                          0.531
# Coquimbo        2010-12-01              13.973                          0.527
# Coro            2010-12-01              26.979                          0.445
# Curico          2010-12-01              15.879                          0.777
# Cusco           2010-12-01              12.030                          0.454
# Girardot        2010-12-01              19.566                          0.334
# Guanare         2010-12-01              23.598                          0.667
# Iquique         2010-12-01              19.522                          0.577
# Mercedes         Argentina   32.95S    66.06W         Mercedes -33.689586
# Neuquen          Argentina   39.38S    68.67W          Neuquen -38.950040
# Oruro              Bolivia   18.48S    67.61W            Oruro -17.979950
# Osorno               Chile   40.99S    72.43W           Osorno -40.569993
# Pucallpa              Peru    8.84S    73.78W         Pucallpa  -8.368909
# Puno                  Peru   15.27S    70.83W             Puno -15.832950
# Rancagua             Chile   34.56S    70.05W         Rancagua -34.170022
# Salta            Argentina   24.92S    65.62W            Salta -24.783359
# Sogamoso          Colombia    5.63N    72.65W         Sogamoso   5.719998
# Soledad           Colombia   10.45N    74.45W          Soledad  10.920017
# Sucre              Bolivia   18.48S    65.92W            Sucre -19.040971
# Tacna                 Peru   18.48S    70.99W            Tacna -18.000001
# Talca                Chile   36.17S    71.60W            Talca -35.455008
# Talcahuano           Chile   36.17S    73.59W       Talcahuano -36.716688
# Temuco               Chile   39.38S    72.83W           Temuco -38.730002
# Trelew           Argentina   42.59S    65.45W           Trelew -43.250036
# Tunja             Colombia    5.63N    72.65W            Tunja   5.550448
# Valdivia             Chile   39.38S    72.83W         Valdivia -39.795001
# Valencia         Venezuela   10.45N    67.91W         Valencia  10.229982
# Valledupar        Colombia   10.45N    72.82W       Valledupar  10.479992
# Valparaiso           Chile   32.95S    71.81W       Valparaiso -33.047764
# Villavicencio     Colombia    4.02N    73.13W    Villavicencio   4.153324
#
#                        lng        pop iso2 iso3  \
# City
# Acarigua        -69.200024   202312.5   VE  VEN
# Antofagasta     -70.400003   295539.0   CL  CHL
# Arequipa        -71.530011   775785.0   PE  PER
# Arica           -70.289984   178446.5   CL  CHL
# Ayacucho        -74.219951   153173.5   PE  PER
# Barinas         -70.250012   261405.5   VE  VEN
# Barquisimeto    -69.299967   962745.0   VE  VEN
# Barrancabermeja -73.849999   177802.0   CO  COL
# Barranquilla    -74.799967  1521245.5   CO  COL
# Bucaramanga     -73.125883   790410.0   CO  COL
# Cabimas         -71.449990   320956.0   VE  VEN
# Calabozo        -67.439977   110907.0   VE  VEN
# Calama          -68.919990   134336.5   CL  CHL
# Caracas         -66.917037  2400339.5   VE  VEN
# Catamarca       -65.780001   162586.0   AR  ARG
# Chillan         -72.105997   149874.0   CL  CHL
# Cochabamba      -66.169977   804138.0   BO  BOL
# Concepcion      -73.050022   550864.0   CL  CHL
# Copiapo         -70.339981   117316.5   CL  CHL
# Coquimbo        -71.343615   159082.5   CL  CHL
# Coro            -69.679995   184098.0   VE  VEN
# Curico          -71.240029   108074.5   CL  CHL
# Cusco           -71.972155   336661.0   PE  PER
# Girardot        -74.809992   121830.5   CO  COL
# Guanare         -69.750017   131964.0   VE  VEN
# Iquique         -70.129968   223012.0   CL  CHL
# Iquitos         -73.250010   448174.5   PE  PER
# Juliaca         -70.139967   234428.0   PE  PER
# Maracay         -67.595807  1007000.0   VE  VEN
# Mendoza         -68.816611   827815.0   AR  ARG
# Mercedes        -65.469968    49345.0   AR  ARG
# Neuquen         -68.059991   213823.5   AR  ARG
# Oruro           -67.129996   227592.5   BO  BOL
# Osorno          -73.160015   144952.0   CL  CHL
# Pucallpa        -74.534996   304917.0   PE  PER
# Puno            -70.033307   111350.0   PE  PER
# Rancagua        -70.739982   222981.5   CL  CHL
# Salta           -65.416638   484646.0   AR  ARG
# Sogamoso        -72.940003   120071.5   CO  COL
# Soledad         -74.769995   520704.0   CO  COL
# Sucre           -65.259516   223287.0   BO  BOL
# Tacna           -70.250012   261042.5   PE  PER
# Talca           -71.670003   186283.5   CL  CHL
# Talcahuano      -73.116659   270521.0   CL  CHL
# Temuco          -72.579999   252015.0   CL  CHL
# Trelew          -65.329951    93128.5   AR  ARG
# Tunja           -73.370028   139445.5   CO  COL
# Valdivia        -73.245023   146509.0   CL  CHL
# Valencia        -67.980021  1569526.5   VE  VEN
# Valledupar      -73.250010   297627.5   CO  COL
# Valparaiso      -71.621014   434969.0   CL  CHL
# Villavicencio   -73.634999   348240.0   CO  COL
#
#                                               province  month  year
# City
# Acarigua                                    Portuguesa     12  2011
# Antofagasta                                Antofagasta     12  2011
# Arequipa                                      Arequipa     12  2011
# Arica                               Arica y Parinacota     12  2011
# Ayacucho                                      Ayacucho     12  2011
# Barinas                                        Barinas     12  2011
# Barquisimeto                                      Lara     12  2011
# Barrancabermeja                              Santander     12  2011
# Barranquilla                                 Atlántico     12  2011
# Bucaramanga                                  Santander     12  2011
# Cabimas                                       Trujillo     12  2011
# Calabozo                                       Guárico     12  2011
# Calama                                     Antofagasta     12  2011
# Caracas                               Distrito Capital     12  2011
# Catamarca                                    Catamarca     12  2011
# Chillan                                        Bío-Bío     12  2011
# Cochabamba                                  Cochabamba     12  2011
# Concepcion                                     Bío-Bío     12  2011
# Copiapo                                        Atacama     12  2011
# Coquimbo                                      Coquimbo     12  2011
# Coro                                            Falcón     12  2011
# Curico                                           Maule     12  2011
# Cusco                                            Cusco     12  2011
# Girardot                                  Cundinamarca     12  2011
# Guanare                                     Portuguesa     12  2011
# Iquique                                       Tarapacá     12  2011
# Iquitos                                         Loreto     12  2011
# Juliaca                                         Callao     12  2011
# Maracay                                         Aragua     12  2011
# Mendoza                                        Mendoza     12  2011
# Mercedes                                      San Luis     12  2011
# Neuquen                                        Neuquén     12  2011
# Oruro                                            Oruro     12  2011
# Osorno                                       Los Lagos     12  2011
# Pucallpa                                       Ucayali     12  2011
# Puno                                            Callao     12  2011
# Rancagua         Libertador General Bernardo O'Higgins     12  2011
# Salta                                            Salta     12  2011
# Sogamoso                                        Boyacá     12  2011
# Soledad                                      Atlántico     12  2011
# Sucre                                       Chuquisaca     12  2011
# Tacna                                            Tacna     12  2011
# Talca                                            Maule     12  2011
# Talcahuano                                     Bío-Bío     12  2011
# Temuco                                    La Araucanía     12  2011
# Trelew                                          Chubut     12  2011
# Tunja                                           Boyacá     12  2011
# Valdivia                                      Los Ríos     12  2011
# Valencia                                      Carabobo     12  2011
# Valledupar                                       Cesar     12  2011
# Valparaiso                                  Valparaíso     12  2011
# Villavicencio                                     Meta     12  2011

# %%
# Uso cuadrados mínimos para predecir
sns.tsplot(data=grouped['AverageTemperature'], time=grouped['lat'], interpolate=False, color='b')


#Santiago_legend = mpatches.Patch(color='red', label='The red data')
#plt.legend(handles=[Santiago_legend])

#plt.plot([3,2,1], label="test2")
# Place a legend to the right of this smaller subplot.

font = {'family': 'normal', 'weight': 'bold', 'size': 20}

sns.plt.rc('font', **font)

sns.plt.rc('axes', labelsize=14)


ax_1 = sns.plt.plot((Santiago['lat'], Santiago['lat']), (Santiago['avg'], Santiago['avg']), 'b-o', label= 'Santiago', marker='o', color='g')
sns.plt.plot((Maracaibo['lat'], Maracaibo['lat']), (Maracaibo['avg'], Maracaibo['avg']), 'b-o', label= 'Maracaibo', marker='o' , color='y')
sns.plt.plot((Oruro['lat'], Oruro['lat']), (Oruro['avg'], Oruro['avg']), 'b-o', label= 'Oruro', marker='o', color='purple')

plt.legend(loc='best', numpoints=1, handlelength=0)

#plt.title('Promedio de temperaturas de diciembre en distintas latitudes')

def armar_matriz_A(s):
    temp = []
    for t in s:
        temp.append([t**3, t, 1,  np.sin(0.8*t)*np.cos(t)])
    return np.array(temp)

def entrenar_y_predecir_en_rangos(df, min_rango_entrenamiento, max_rango_entrenamiento):
    regr = linear_model.LinearRegression(fit_intercept=False)
    
    
    # Entreno el modelo
    df_e = df[(df['lat'] <= max_rango_entrenamiento) & (df['lat'] >= min_rango_entrenamiento)]
    A_e = armar_matriz_A(df_e['lat'])
    regr.fit(A_e, df_e['AverageTemperature'])

    # Me fijo la aproximación que se realizó
    df_e['p'] = regr.predict(A_e)
    df_e['Latitud'] = df_e['lat']
    sns.tsplot(time=df_e['Latitud'], data=df_e['p'], color='r')
    return 1

def predecir(k):
    return entrenar_y_predecir_en_rangos(grouped, k-100, k)
    
plt.ylabel('AVG Temperatura')
ECM = predecir(50)
sns.plt.show()

# %% [markdown]
# # Y si no es una seria de tiempo?

# %%
# Un par de cosas más de pandas

years = [2004]*6 + [2005]*6 + [2006]*6
delays = list(np.random.randn(6)+80) + list(np.random.randn(6)+5) + list(np.random.randn(6)+50)
delays[2] = 5
delays[7] = 80

df1 = pd.DataFrame({
    'year': years,
    'delay': delays
})

df1
# Out:
#         delay  year
# 0   80.821911  2004
# 1   81.994264  2004
# 2    5.000000  2004
# 3   77.742141  2004
# 4   80.080482  2004
# 5   80.356484  2004
# 6    4.082986  2005
# 7   80.000000  2005
# 8    5.537343  2005
# 9    5.836535  2005
# 10   5.402303  2005
# 11   5.086106  2005
# 12  50.606251  2006
# 13  50.135174  2006
# 14  50.751529  2006
# 15  50.293271  2006
# 16  51.094942  2006
# 17  48.922509  2006

# %%
# Groupby y sacar outliers

mascara = df1.groupby('year')['delay'].apply(mascara_outliers)
df1 = df1[mascara]
df1
# Out:
#         delay  year
# 0   80.821911  2004
# 1   81.994264  2004
# 3   77.742141  2004
# 4   80.080482  2004
# 5   80.356484  2004
# 6    4.082986  2005
# 8    5.537343  2005
# 9    5.836535  2005
# 10   5.402303  2005
# 11   5.086106  2005
# 12  50.606251  2006
# 13  50.135174  2006
# 14  50.751529  2006
# 15  50.293271  2006
# 16  51.094942  2006
# 17  48.922509  2006

# %%
# Groupby y calcular promedio

promedio = df1.groupby('year').aggregate(['mean', 'std', 'count'])
promedio
# Out:
#           delay
#            mean       std count
# year
# 2004  80.199056  1.556117     5
# 2005   5.189055  0.674536     5
# 2006  50.300613  0.755552     6
